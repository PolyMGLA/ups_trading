# %%
import pandas as pd
import os

# %%
os.chdir('..')
os.chdir('..')
os.getcwd()
# Out:
# 'c:\\Users\\ciell\\Desktop\\lessons\\ups'

# %%
PATH = os.getcwd() + '\\data\\clear_data'
PATH
# Out:
# 'c:\\Users\\ciell\\Desktop\\lessons\\ups\\data\\clear_data'

# %%
close = pd.read_csv(PATH + '\\' + 'close.csv', index_col='openTime')
close.index = pd.to_datetime(close.index)
close
# Out:
#                            1000000MOGUSDT  1000BONKUSDC  1000BONKUSDT  \
# openTime
# 2022-09-09 13:00:00+00:00             NaN           NaN           NaN
# 2022-09-09 13:05:00+00:00             NaN           NaN           NaN
# 2022-09-09 13:10:00+00:00             NaN           NaN           NaN
# 2022-09-09 13:15:00+00:00             NaN           NaN           NaN
# 2022-09-09 13:20:00+00:00             NaN           NaN           NaN
# ...                                   ...           ...           ...
# 2025-01-09 23:35:00+00:00          1.9446      0.027126      0.027130
# 2025-01-09 23:40:00+00:00          1.9446      0.027162      0.027146
# 2025-01-09 23:45:00+00:00          1.9438      0.027176      0.027156
# 2025-01-09 23:50:00+00:00          1.9481      0.027198      0.027181
# 2025-01-09 23:55:00+00:00          1.9473      0.027196      0.027175
#
#                            1000CATUSDT  1000CHEEMSUSDT  1000FLOKIUSDT  \
# openTime
# ...
